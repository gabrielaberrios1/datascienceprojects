# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#house_df=pd.read_excel("Luis Abreu and Associates Cayey total 2020-2022.xlsx")
house_df=pd.read_excel("Luis Abreu and Associates Cayey total 2020-2022.xlsx")

# %%
house_df
# Out:
#      Reference Photo     Block               Street                Ward Name  \
# 0       267584   Yes       D-6  ZORZAL (4 EAST) ST.       ALTURAS DE BEATRIZ
# 1       266487   Yes      C-23                  NaN       ALTURAS DE BEATRIZ
# 2       265258   Yes       L-9       RUISEÃ‘OR  ST.       ALTURAS DE BEATRIZ
# 3       258841   Yes      B-19     SABANERA (8) ST.       ALTURAS DE BEATRIZ
# 4       257587   Yes      F-14                8 ST.       ALTURAS DE BEATRIZ
# ..         ...   ...       ...                  ...                      ...
# 203     257118   Yes      D-23                D ST.           VILLA VERDE II
# 204     254197   Yes        41                2 ST.  VILLAS DE JOHNNY TOLEDO
# 205     259000   Yes      C-34      PASEO DE LAUREL       VILLAS DE MONTESOL
# 206     255320   Yes  C-1B (2)                A ST.       VILLAS DE MONTESOL
# 207     257488   Yes      A-45           ROBLES ST.       VILLAS DE SAN JOSE
#
# ...

# %%
house_df.shape
# Out:
# (208, 80)

# %%
house_df.dropna(subset=['Beds'],how='all').shape
# Out:
# (204, 80)

# %%
house_df['Beds'].value_counts()
# Out:
# 3.0    116
# 4.0     56
# 2.0     17
# 5.0      9
# 6.0      5
# 7.0      1
# Name: Beds, dtype: int64

# %%
house_df['Lot Area(SF)'].fillna(value='VARIOUS',inplace=True)
house_df.shape
# Out:
# (208, 80)

# %%
house_df[]

# %%
house_df['Lot Area(SF)'].value_counts(dropna=False)
# Out:
# 3228.0      6
# VARIOUS     6
# 0.0         4
# 3357.12     3
# 3497.0      3
#            ..
# 2926.72     1
# 1506.4      1
# 2291.88     1
# 2367.2      1
# 14838.04    1
# Name: Lot Area(SF), Length: 171, dtype: int64

# %%
#house_df['Rooms']=house_df['Rooms'].fillna(house_df['Rooms'].mean())
#house_df['Baths']=house_df['Baths'].fillna(house_df['Baths'].mean())
#house_df['Year Built']=house_df['Year Built'].fillna(house_df['Year Built'].mean())
house_df['Lot Area(SF)']=house_df['Lot Area(SF)'].fillna(house_df['Lot Area(SF)'].mean())

# %%
house_df.columns

#house_df.columns
#'Floors','Zipcode','Age','GLA','House Area','Days on market','Contract Price','Total Cost New'
# Out:
# Index(['Reference', 'Photo', 'Block', 'Street', 'Ward Name', 'Municipality',
#        'Sale Price', 'App. Value', 'Loan Type', 'Sale Type', 'Date Sold',
#        'Lot Area', 'Type', 'Age', 'Cond', 'Story', 'Unit', 'Construction',
#        'Effective Age', 'Units (SQFT)', 'Units (Roomcount)', 'Units (Rent)',
#        'Units (Comments)', 'Rooms', 'Beds', 'Baths', 'GLA', 'CP/GR',
#        'App Code', 'Other Improvements', 'Unnamed: 30', 'Unnamed: 31',
#        'Remodeled Kitchen', 'Remodeled Bath', 'Data Source', 'Entry Date',
#        'Cadastre numbrer', 'Seller', 'Buyer', 'House Area', 'Dwelling',
#        'Lot Area.1', 'Opinion Site Value', 'Zipcode', 'GPS', 'Days on market',
#        'DOM Comments', 'Zone', 'Quote Price', 'Views', 'Floors',
#        'Appraiser Name', 'Concession on sale', 'Contract Price',
#        'Contract Date', 'Effective Date', 'Fema flood hazard area',
#        'Fema flood zone', 'Fema map', 'Fema map date', 'Year Built', 'Quality',
# ...

# %%
house_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
sns.scatterplot(x='Lot Area(SF)', y='Sale Price',data=house_df)
# Out:
# <AxesSubplot:xlabel='Lot Area(SF)', ylabel='Sale Price'>

# %%
house_df.hist(bins=79,figsize=(79,79),color = 'b')
# Out:
# array([[<AxesSubplot:title={'center':'Reference'}>,
#         <AxesSubplot:title={'center':'Sale Price'}>,
#         <AxesSubplot:title={'center':'App. Value'}>,
#         <AxesSubplot:title={'center':'Date Sold'}>,
#         <AxesSubplot:title={'center':'Lot Area'}>,
#         <AxesSubplot:title={'center':'Age'}>],
#        [<AxesSubplot:title={'center':'Story'}>,
#         <AxesSubplot:title={'center':'Unit'}>,
#         <AxesSubplot:title={'center':'Effective Age'}>,
#         <AxesSubplot:title={'center':'Rooms'}>,
#         <AxesSubplot:title={'center':'Beds'}>,
#         <AxesSubplot:title={'center':'Baths'}>],
#        [<AxesSubplot:title={'center':'GLA'}>,
#         <AxesSubplot:title={'center':'App Code'}>,
#         <AxesSubplot:title={'center':'Unnamed: 30'}>,
#         <AxesSubplot:title={'center':'Entry Date'}>,
#         <AxesSubplot:title={'center':'House Area'}>,
#         <AxesSubplot:title={'center':'Dwelling'}>],
# ...

# %%
f,ax= plt.subplots(figsize = (30,30))
sns.heatmap(house_df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
house_df_sample = house_df[[ 'Sale Price' ,'Rooms', 'Baths','Year Built','Lot Area(SF)','Floors','Zipcode']]

# %%
house_df_sample
# Out:
#      Sale Price  Rooms  Baths  Year Built  Lot Area(SF)  Floors  Zipcode
# 0        130000    6.0    2.0      2001.0       3228.00     1.0      736
# 1        130000    6.0    2.0      2001.0       3228.00     1.0      736
# 2        120000    6.0    2.0      2001.0       3228.00     1.0      736
# 3        120000    6.0    2.0      2003.0       3152.68     1.0      736
# 4        132000    6.0    2.0      2001.0       3228.00     1.0      736
# ..          ...    ...    ...         ...           ...     ...      ...
# 203      123000    6.0    2.0      1994.0       5089.48     1.0      736
# 204       80000    6.0    1.1      2009.0       1119.04     1.0      736
# 205      125000    6.0    1.0      1996.0      20250.32     1.0      736
# 206      125275    8.0    2.0      2000.0       9608.68     1.0      736
# 207      215000    8.0    2.1      2001.0      14838.04     1.0      736
#
# [208 rows x 7 columns]

# %%
sns.pairplot(house_df_sample)

# %%
sns.pairplot(house_df_sample)

# %%
#selected_features=['Rooms', 'Baths','Year Built','Lot Area(SF)','Floors','Zipcode','Age','GLA','House Area','Days on market','Contract Price','Total Cost New']
#selected_features=[
       #'Sale Price', 'App. Value', 
      ## 'Units (Comments)', 'Rooms', 'Beds', 'Baths', 'GLA', 'CP/GR',
      # 'App Code', 'Other Improvements', 'Unnamed: 30', 'Unnamed: 31',
       #'Remodeled Kitchen', 'Remodeled Bath', 'Data Source', 'Entry Date',
      # 'Cadastre numbrer', 'Seller', 'Buyer', 'House Area', 'Dwelling',
      # 'Lot Area.1', 'Opinion Site Value', 'Zipcode', 'GPS', 'Days on market',
      # 'DOM Comments', 'Zone', 'Quote Price', 'Views', 'Floors',
      # 'Appraiser Name', 'Concession on sale', 'Contract Price',
      # 'Contract Date', 'Effective Date', 'Fema flood hazard area',
     #  'Fema flood zone', 'Fema map', 'Fema map date', 'Year Built', 'Quality',
     #  'Depreciation', 'Lot Area(SF)', 'Original listing date',
     #  'Original listing price', 'Subsequent listing date',
     #  'Subsequent listing price', 'Final listing price',
      # 'Total Cost New']
#selected_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement']
selected_features=['Lot Area(SF)']

# %%
x=house_df[selected_features]

# %%
x
# Out:
#     Lot Area(SF)
# 0         3228.0
# 1         3228.0
# 2         3228.0
# 3        3152.68
# 4         3228.0
# ..           ...
# 203      5089.48
# 204      1119.04
# 205     20250.32
# 206      9608.68
# 207     14838.04
#
# [208 rows x 1 columns]

# %%
#y=house_df['Sale Price']
y=house_df['Sale Price']

# %%
y
# Out:
# 0      130000
# 1      130000
# 2      120000
# 3      120000
# 4      132000
#         ...
# 203    123000
# 204     80000
# 205    125000
# 206    125275
# 207    215000
# Name: Sale Price, Length: 208, dtype: int64

# %%
x.shape
# Out:
# (208, 1)

# %%
y.shape
# Out:
# (208,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled =scaler.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32532/3318581491.py in <module>
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 scaler=MinMaxScaler()
# ----> 3 x_scaled =scaler.fit_transform(x)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     361         # Reset internal state before fitting
#     362         self._reset()
# --> 363         return self.partial_fit(X, y)
#     364
#     365     def partial_fit(self, X, y=None):
# ...

# %%
x_scaled
# Out:
# array([[0.01526562],
#        [0.01526562],
#        [0.01526562],
#        [0.01490942],
#        [0.01526562],
#        [0.01526562],
#        [0.01526562],
#        [0.18624059],
#        [0.10202524],
#        [0.12812945],
#        [0.10797883],
#        [0.11469571],
#        [0.10894565],
#        [0.01587625],
#        [0.01587625],
#        [0.01694484],
#        [0.01994708],
#        [0.2831264 ],
#        [0.0212701 ],
#        [0.09220436],
#        [0.04477911],
#        [0.01954   ],
#        [0.02803786],
#        [0.21789131],
#        [0.08930389],
#        [0.08660696],
#        [0.03516182],
#        [0.19311012],
#        [0.        ],
#        [0.        ],
#        [0.03154895],
#        [0.03689192],
#        [0.03821494],
#        [0.00585177],
#        [0.01038062],
#        [0.01414614],
#        [0.01791166],
#        [0.05398942],
#        [0.0334826 ],
#        [0.02819051],
#        [0.        ],
#        [0.05068186],
#        [0.01908203],
# ...

# %%
scaler.data_max_
# Out:
# array([211455.52])

# %%
scaler.data_min_
# Out:
# array([0.])

# %%
y=y.values.reshape(-1,1)

# %%
y_scaled=scaler.fit_transform(y)

# %%
y_scaled
# Out:
# array([[0.32280702],
#        [0.32280702],
#        [0.2877193 ],
#        [0.2877193 ],
#        [0.32982456],
#        [0.30526316],
#        [0.28736842],
#        [0.53333333],
#        [0.3754386 ],
#        [0.24561404],
#        [0.3754386 ],
#        [0.43508772],
#        [0.51929825],
#        [0.27017544],
#        [0.2245614 ],
#        [0.32280702],
#        [0.21754386],
#        [0.4877193 ],
#        [0.03508772],
#        [0.44912281],
#        [0.32280702],
#        [0.21754386],
#        [0.28070175],
#        [0.21754386],
#        [0.33684211],
#        [0.84912281],
#        [0.18245614],
#        [0.41052632],
#        [0.42807018],
#        [0.39298246],
#        [0.56842105],
#        [0.53333333],
#        [0.52631579],
#        [0.06666667],
#        [0.2       ],
#        [0.07719298],
#        [0.2       ],
#        [0.41403509],
#        [0.56842105],
#        [0.44561404],
#        [0.54736842],
#        [0.77894737],
#        [0.53333333],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,X_test,y_train,y_test = train_test_split(x_scaled, y_scaled,test_size = 0.25)

# %%
x_train.shape
# Out:
# (156, 1)

# %%
X_test.shape
# Out:
# (52, 1)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
 
model = Sequential()
model.add(Dense(100,input_dim=1,activation='relu'))
model.add(Dense(100,activation='relu'))

model.add(Dense(100,activation='relu'))
model.add(Dense(200,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 100)               200
#
#  dense_16 (Dense)            (None, 100)               10100
#
#  dense_17 (Dense)            (None, 100)               10100
#
#  dense_18 (Dense)            (None, 200)               20200
#
#  dense_19 (Dense)            (None, 1)                 201
#
# ...
# Total params: 40,801
# Trainable params: 40,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',loss='mean_squared_error')

# %%
epochs_hist = model.fit(x_train, y_train, epochs = 100, batch_size = 31, validation_split=0.2)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1815 - val_loss: 0.1616
# Epoch 2/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1347 - val_loss: 0.1025
# Epoch 3/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0798 - val_loss: 0.0443
# Epoch 4/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0469 - val_loss: 0.0322
# Epoch 5/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0592 - val_loss: 0.0345
# Epoch 6/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0475 - val_loss: 0.0301
# Epoch 7/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0435 - val_loss: 0.0355
# Epoch 8/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0434 - val_loss: 0.0378
# Epoch 9/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0436 - val_loss: 0.0359
# Epoch 10/100
# ...

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss','Validation Loss'])

# %%
#X_test_1 =np.array([[6,2,2001,3228,1,736,21,984,90,2,140000,104820]])
X_test_1 = np.array([[ 3228 ]])
scaler_1=MinMaxScaler()

X_test_scaled_1=scaler_1.fit_transform(X_test_1)

y_predict_1=model.predict(X_test_scaled_1)

y_predict_1=scaler.inverse_transform(y_predict_1)

y_predict_1
# Out:
# 1/1 [==============================] - 0s 19ms/step
# array([[105222.26]], dtype=float32)

# %%
y_predict=model.predict(X_test)
plt.plot(y_test,y_predict,"^",color='r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# 169/169 [==============================] - 0s 374us/step
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig=scaler.inverse_transform(y_predict)
y_test_orig=scaler.inverse_transform(y_test)

# %%
plt.plot(y_test_orig,y_predict_orig,'^',color='r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
plt.xlim(0,500000)
plt.ylim(0,300000)
# Out:
# (0.0, 300000.0)

# %%
#lenght of the testing data
k=X_test.shape[1]
n=len(X_test)
n
# Out:
# 5404

# %%
#
k
# Out:
# 7

# %%
from sklearn.metrics import  r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE=float(format(np.sqrt(mean_squared_error(y_test_orig,y_predict_orig)),'.3f'))

MSE=mean_squared_error(y_test_orig, y_predict_orig)
 
MAE=mean_absolute_error(y_test_orig, y_predict_orig)

r2=r2_score(y_test_orig,y_predict_orig)

adj_r2=1-(1-r2)*(n-1)/(n-k-1)

print('RMSE=',RMSE, '\nMSE=',MSE,'\nMAE=',MAE,'\nR2=',r2,'\nAdjusted R2=',adj_r2)
# Out:
# RMSE= 245438.524
# MSE= 60240069114.694534
# MAE= 158845.81724474925
# R2= 0.5742039470998533
# Adjusted R2= 0.5736515800927553

# %% [markdown]
# #bedrooms,bathrooms,sqft liiving,sqft lot,floors,sqftabove,sqftbasement,yr_renovated,zipcode,lat,long,sqft_living,sft_lot
# X=house_df[selected_features]

# %%
Results:Due to lack of data the accuracy was as expected. Need more data to test the model.
